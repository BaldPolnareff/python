# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# # Introduction to Exploratory Data Analysis

# %% [markdown]
# ## Step 0: Importing Data

# %%
df = pd.read_csv('Data/coaster_db.csv')

# %%
df
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %% [markdown]
# ## Step 1: Data Understanding
#
# + Dataframe `shape`
# + `head` and `tail`
# + `dtypes`
# + `describe`

# %%
df.shape
# Out:
# (1087, 56)

# %%
pd.options.display.max_columns = 200

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ## Step 2: Data Preparation

# %% [markdown]
# + Dropping irrelevant columns and/or rows
# + Removing duplicate columns and/or rows
# + Renaming columns in a meaningful way if necessary
# + Creating features

# %% [markdown]
# ### Removing unnecessary data

# %%
df.head(2)
# Out:
#          coaster_name          Length             Speed       Location  \
# 0  Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)   Coney Island
# 1   Flip Flap Railway             NaN               NaN  Sea Lion Park
#
#     Status   Opening date  Type            Manufacturer Height restriction  \
# 0  Removed  June 16, 1884  Wood  LaMarcus Adna Thompson                NaN
# 1  Removed           1895  Wood            Lina Beecher                NaN
#
#          Model        Height  Inversions Lift/launch system Cost  \
# 0  Lift Packed  50 ft (15 m)         NaN            gravity  NaN
# 1          NaN           NaN         1.0                NaN  NaN
#
#                                               Trains  \
# 0                                                NaN
# 1  a single car. Riders are arranged 1 across in ...
#
#                 Park section Duration              Capacity G-force  \
# 0  Coney Island Cyclone Site     1:00  1600 riders per hour     2.9
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df = df[['coaster_name', 
    #   'Length', 'Speed', 
       'Location', 
    # 'Status', 'Opening date',
    #   'Type', 
       'Manufacturer', 
    #   'Height restriction', 'Model', 'Height',
    #   'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
    #   'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
    #   'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
    #   'Track layout', 'Fastrack available', 'Soft opening date.1',
    #   'Closing date', 
       'Opened', 
    #   'Replaced by', 'Website',
    #   'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
    #   'Single rider line available', 'Restraint Style',
    #   'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
    #   'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #   'height_value', 'height_unit', 
       'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.shape, df.dtypes
# Out:
# ((1087, 13),
#  coaster_name           object
#  Location               object
#  Manufacturer           object
#  Opened                 object
#  year_introduced         int64
#  latitude              float64
#  longitude             float64
#  Type_Main              object
#  opening_date_clean     object
#  speed_mph             float64
#  height_ft             float64
#  Inversions_clean        int64
#  Gforce_clean          float64
#  dtype: object)

# %%
df['opening_date_clean'] # It's an object but it's better to set it as a datetime type
# Out:
# 0       1884-06-16
# 1       1895-01-01
# 2              NaN
# 3       1901-01-01
# 4       1901-01-01
#            ...
# 1082           NaN
# 1083    2022-01-01
# 1084    2016-06-16
# 1085           NaN
# 1086    2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: object

# %%
# df['opening_date_clean'].astype('datetime64[ns]') one way to do it
pd.to_datetime(df['opening_date_clean'])
# Out:
# 0      1884-06-16
# 1      1895-01-01
# 2             NaT
# 3      1901-01-01
# 4      1901-01-01
#           ...
# 1082          NaT
# 1083   2022-01-01
# 1084   2016-06-16
# 1085          NaT
# 1086   2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: datetime64[ns]

# %%
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %% [markdown]
# ### Renaming columns

# %%
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Manufacturer', 'Opened', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df = df.rename(columns={'coaster_name':'Coaster_Name', 
                   'opening_date_clean':'Opening_Date', 
                   'year_introduced':'Year_Introduced', 
                   'latitude':'Latitude', 
                   'longitude':'Longitude', 
                   'speed_mph':'Speed_mph', 
                   'height_ft':'Height_ft'})

# %%
df
# Out:
#                                 Coaster_Name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df.isna().sum()
# Out:
# Coaster_Name           0
# Location               0
# Manufacturer          59
# Opened              1060
# Year_Introduced        0
# Latitude             275
# Longitude            275
# Type_Main              0
# Opening_Date         250
# Speed_mph            150
# Height_ft            916
# Inversions_clean       0
# Gforce_clean         725
# dtype: int64

# %%
df.loc[df.duplicated()] # No duplicated rows!
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Manufacturer, Opened, Year_Introduced, Latitude, Longitude, Type_Main, Opening_Date, Speed_mph, Height_ft, Inversions_clean, Gforce_clean]
# Index: []

# %% [markdown]
# However, we might want to check duplication for columns as well.

# %%
df.loc[df.duplicated(subset=['Coaster_Name'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                                            Manufacturer Opened  \
# 43                                   Traver Engineering    NaN
# ...

# %% [markdown]
# Let's check for a row that contains duplicates for the Coaster Name column using some query and let's figure out what's going on.

# %%
df.query('Coaster_Name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location        Manufacturer Opened  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Traver Engineering    NaN
# 43  Crystal Beach Cyclone  Crystal Beach Park  Traver Engineering    NaN
#
#     Year_Introduced  Latitude  Longitude Type_Main Opening_Date  Speed_mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     Height_ft  Inversions_clean  Gforce_clean
# 39        NaN                 0           4.0
# 43        NaN                 0           4.0

# %% [markdown]
# There's an almost duplicate row, but it's not exactly the same. Let's check the difference.
#
# The Year Introduced column is different. This might be an error in the dataset, or the park might have had a first opening that might have been delayed for some reason.
#
# We are going to keep the row with the first opening date, so we are going to drop the row with the second opening date.

# %% [markdown]
# Let's check more specifically for duplicates in the Coaster Name, Location, and Openings Date columns to get more insight into the data.

# %%
df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082     True
# 1083    False
# 1084     True
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %% [markdown]
# Let's locate the opposite condition!

# %%
df = df.loc[~df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date'])].reset_index(drop=True)

# %%
df
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %% [markdown]
# ## Step 3: Feature Understanding
#
# We cleaned the data and got a first understanding of the set. We're now ready to do a univariate analysis of the data.
#
# + Plotting Feature Distributions
#   + Histogram
#   + KDE (Kernel Density Estimation)
#   + Boxplot

# %%
df
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df['Year_Introduced'].value_counts()
# Out:
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: Year_Introduced, Length: 101, dtype: int64

# %%
N = 10
ax = df['Year_Introduced'].value_counts().head(N).plot(kind='bar', title=f'Top {N} Years of Introduction')
ax.set_xlabel('Year')
ax.set_ylabel('Rollercoasters')
plt.show()

# %%
N_bins = 40
ax = df['Speed_mph'].plot(kind='hist', bins=N_bins, title=r'Coaster speed $[mph]$')
ax.set_xlabel(r'$[mph]$')
plt.show()

# %% [markdown]
# Let's see a KDE (Kernel Density Estimation) plot for the Speed column, which is usually a bit easier to read than a histogram, as data is normalized.

# %%
ax = df['Speed_mph'].plot(kind='kde', title=r'Coaster speed $[mph]$')
ax.set_xlabel(r'$[mph]$')
plt.show()

# %% [markdown]
# ## Step 4: Feature Relationships
#
# + Scatterplot
# + Heatmap Correlation
# + Pairplot
# + Groupby Comparisons

# %%
df.plot(kind='scatter', x='Speed_mph', y='Height_ft', title='Coaster Speed vs Height', 
        xlabel=r'Speed $[mph]$', ylabel=r'Height $[ft]$')
plt.show()

# %% [markdown]
# We can do more stuff using seaborn!

# %%
sns.scatterplot(x='Speed_mph', y='Height_ft', data=df, hue='Year_Introduced')
plt.show()

# %%
sns.pairplot(vars=['Year_Introduced', 'Speed_mph', 'Height_ft', 'Inversions_clean', 'Gforce_clean'] , data=df, 
             hue='Type_Main')
plt.show()

# %% [markdown]
# We can check the correlation among the known numerical features, but let's drop the non-available values first.

# %%
df_corr = df[['Year_Introduced', 'Speed_mph', 'Height_ft', 'Inversions_clean', 'Gforce_clean']].dropna().corr()
df_corr
# Out:
#                   Year_Introduced  Speed_mph  Height_ft  Inversions_clean  \
# Year_Introduced          1.000000   0.171978   0.135413         -0.209887
# Speed_mph                0.171978   1.000000   0.733999         -0.028705
# Height_ft                0.135413   0.733999   1.000000         -0.079736
# Inversions_clean        -0.209887  -0.028705  -0.079736          1.000000
# Gforce_clean             0.160247   0.607383   0.466482          0.275991
#
#                   Gforce_clean
# Year_Introduced       0.160247
# Speed_mph             0.607383
# Height_ft             0.466482
# Inversions_clean      0.275991
# Gforce_clean          1.000000

# %%
sns.heatmap(df_corr, annot=True)
plt.show()

# %% [markdown]
# ## Step 5: Ask questions about the data
#
# + Answer using meaningful visualizations

# %% [markdown]
# What are the locations of the fastest roller coasters (minimum of 10 coasters)?

# %%
N_coasters = 10
fastest_coasters = df.query('Location != "Other"').groupby('Location')['Speed_mph'].agg(['mean', 'count']).query('count >= @N_coasters').sort_values('mean')

# %%
fastest_coasters
# Out:
#                                  mean  count
# Location
# Alton Towers                42.791667     12
# Carowinds                   43.571429     14
# Kings Island                49.273684     19
# Hersheypark                 50.576923     13
# Kings Dominion              52.083333     12
# Six Flags Great Adventure   53.036364     11
# Canada's Wonderland         53.533333     12
# Six Flags Magic Mountain    57.241176     17
# Cedar Point                 57.833333     18
# Busch Gardens Williamsburg  58.318182     11

# %%
ax = fastest_coasters.plot(kind='barh', figsize=(12, 5), title=f'Top {N_coasters} fastest coasters')
#ax.set_xlabel(r'Speed $[mph]$')
ax.set_ylabel('Location')
plt.show()
